# %%
import csv

questions = [] 
answers = []
missed_rows = dict()

with open('survey.tab') as file:
    reader = csv.reader(file, delimiter='\t') 
    counter = 0
    for row in reader:
        try:
            if row[0]=='QUES':
                question = dict()
                question['row_count'] = counter
                question['platform'] = row[1]
                question['q_id'] = row[2]
                question['text'] = row[3]
                question['answers'] = row[4:]
                questions.append(question)
            elif row[0]=='RES':
                answer = dict()
                answer['row_count'] = counter
                answer['platform'] = row[1]
                answer['cat_id'] = row[2]
                answer['q_id'] = row[3]
                answer['text'] = row[4:]
                answers.append(answer)
            elif row[0]=='STAT':
                print('GENERAL STATISTICS ABOUT FILE')
                print(counter, row)
            else:
                # row[0] since all missed rows have len < 1
                answers[-1]['text'].append(row[0])
            counter += 1
        except IndexError:
            pass
# Out:
# GENERAL STATISTICS ABOUT FILE
# 659727 ['STAT', 'typeform', 'question_count', '600']
# GENERAL STATISTICS ABOUT FILE
# 659728 ['STAT', 'typeform', 'response_count', '4567']
# GENERAL STATISTICS ABOUT FILE
# 659729 ['STAT', 'typeform', 'response_matched_count', '3589']
# GENERAL STATISTICS ABOUT FILE
# 659730 ['STAT', 'basepaws', 'question_count', '208']
# GENERAL STATISTICS ABOUT FILE
# 659731 ['STAT', 'basepaws', 'response_count', '5913']
# GENERAL STATISTICS ABOUT FILE
# 659732 ['STAT', 'basepaws', 'response_matched_count', '5748']

# %%
import pandas as pd

answers = pd.DataFrame(answers)
questions = pd.DataFrame(questions)

# %%
df = questions.merge(answers, on='q_id', how='outer', suffixes=('_q', '_a'))
df = df.drop(columns=['row_count_q', 'row_count_a'])
df
# Out:
#        platform_q          q_id  \
# 0        typeform  rawHf21eD8l4
# 1        typeform  iuqFDuVsNk4U
# 2        typeform  D6cJqgZ5iMZu
# 3        typeform  ikt7ob1tSGOX
# 4        typeform  Lxk3tuDlecAr
# ...           ...           ...
# 670470   basepaws           379
# 670471   basepaws           380
# 670472   basepaws           383
# 670473   basepaws           382
# 670474   basepaws           374
#
#                                                    text_q  \
# 0       We know it’s all about your cat, but first we ...
# 1                                              Your name?
# 2                                             Your email?
# 3                                        Your cat's name?
# 4       If you were given a survey code, please enter ...
# ...                                                   ...
# 670470           What is your favorite thing about _____?
# 670471  Which of the following areas do you hope to le...
# 670472  Which of the following does _____ have access ...
# 670473  Which of the following problems or concerns do...
# 670474  _____'s date of birth or estimated age?This qu...
#
#                                                   answers platform_a  \
# 0                                                    [-1]        NaN
# 1                                                    [-1]        NaN
# 2                                                    [-1]        NaN
# 3                                                    [-1]        NaN
# 4                                                    [-1]   typeform
# ...                                                   ...        ...
# 670470  [S/he is low maintenance, S/he likes to spend ...        NaN
# 670471  [Urinary behaviors, Weight, Biting, Scratching...        NaN
# 670472  [Air Prey Toys, Ground Prey Toys, Catnip, Food...        NaN
# 670473  [Inappropriate Scratching, Inappropriate Urina...        NaN
# 670474                                               [-1]        NaN
#
#                           cat_id  text_a
# 0                            NaN     NaN
# 1                            NaN     NaN
# 2                            NaN     NaN
# 3                            NaN     NaN
# 4       AA.ANV.27.31001907051020  [none]
# ...                          ...     ...
# 670470                       NaN     NaN
# 670471                       NaN     NaN
# 670472                       NaN     NaN
# 670473                       NaN     NaN
# 670474                       NaN     NaN
#
# [670475 rows x 7 columns]

# %%
df = df.astype(str).drop_duplicates()
df
# Out:
#        platform_q          q_id  \
# 0        typeform  rawHf21eD8l4
# 1        typeform  iuqFDuVsNk4U
# 2        typeform  D6cJqgZ5iMZu
# 3        typeform  ikt7ob1tSGOX
# 4        typeform  Lxk3tuDlecAr
# ...           ...           ...
# 670470   basepaws           379
# 670471   basepaws           380
# 670472   basepaws           383
# 670473   basepaws           382
# 670474   basepaws           374
#
#                                                    text_q  \
# 0       We know it’s all about your cat, but first we ...
# 1                                              Your name?
# 2                                             Your email?
# 3                                        Your cat's name?
# 4       If you were given a survey code, please enter ...
# ...                                                   ...
# 670470           What is your favorite thing about _____?
# 670471  Which of the following areas do you hope to le...
# 670472  Which of the following does _____ have access ...
# 670473  Which of the following problems or concerns do...
# 670474  _____'s date of birth or estimated age?This qu...
#
#                                                   answers platform_a  \
# 0                                                  ['-1']        nan
# 1                                                  ['-1']        nan
# 2                                                  ['-1']        nan
# 3                                                  ['-1']        nan
# 4                                                  ['-1']   typeform
# ...                                                   ...        ...
# 670470  ['S/he is low maintenance', 'S/he likes to spe...        nan
# 670471  ['Urinary behaviors', 'Weight', 'Biting', 'Scr...        nan
# 670472  ['Air Prey Toys', 'Ground Prey Toys', 'Catnip'...        nan
# 670473  ['Inappropriate Scratching', 'Inappropriate Ur...        nan
# 670474                                             ['-1']        nan
#
#                           cat_id    text_a
# 0                            nan       nan
# 1                            nan       nan
# 2                            nan       nan
# 3                            nan       nan
# 4       AA.ANV.27.31001907051020  ['none']
# ...                          ...       ...
# 670470                       nan       nan
# 670471                       nan       nan
# 670472                       nan       nan
# 670473                       nan       nan
# 670474                       nan       nan
#
# [657502 rows x 7 columns]

# %%
df.value_counts('q_id')
# Out:
# q_id
# 181             5921
# 171             5920
# 261             5883
# 225             5880
# 210             5880
#                 ...
# iAUjYizWswud       1
# BTkGyh0HPCEP       1
# hydpzSqlMELo       1
# NEQRmfEKRiL0       1
# QG8QblnJXrzW       1
# Length: 803, dtype: int64

# %%
answers.value_counts('q_id')
# Out:
# q_id
# 181             5943
# 171             5925
# 261             5901
# 271             5881
# 259             5881
#                 ...
# NEQRmfEKRiL0       1
# jHeu1NoNlpPN       1
# wLuCikWCwGSc       1
# xEgNhh2frTPJ       1
# tjl3KuGBIOvG       1
# Length: 558, dtype: int64

# %%
answers.value_counts('cat_id')
# Out:
# cat_id
# AM.74.DSC002467                               196
# DF.67.31001812150642                          193
# UNMATCHED.3486ecf376676672638e4513100536a8    178
# UNMATCHED.9e2d78e2be8af0d4e904e509652af17c    168
# AR.54.1543197                                 165
#                                              ...
# UNMATCHED.d1d6fe2bc5c057f50e87bea1d5b81675     25
# CM.25.31001812151008                           24
# CM.2.31001812150516                            23
# UNMATCHED.9acc4f7b5e4585c189a63801810d1dd2     22
# UNMATCHED.b1cf1d2a8892b2ce897b716f761d93c0      8
# Length: 9558, dtype: int64

# %%
df[df['cat_id'] == 'AM.74.DSC002467']
# Out:
#        platform_x           cat_id          q_id  \
# 171      typeform  AM.74.DSC002467  JukZb7tRAOhA
# 1652     typeform  AM.74.DSC002467  KgnMO5n4s6Fd
# 3132     typeform  AM.74.DSC002467  r6hdbeY4cSEA
# 3328     typeform  AM.74.DSC002467  r6hdbeY4cSEA
# 4446     typeform  AM.74.DSC002467  SNhPhCORtzKP
# ...           ...              ...           ...
# 645670   basepaws  AM.74.DSC002467           252
# 651550   basepaws  AM.74.DSC002467           236
# 657430   basepaws  AM.74.DSC002467           237
# 663297   basepaws  AM.74.DSC002467           221
# 667031   basepaws  AM.74.DSC002467           346
#
#                                                    text_x platform_y  \
# 171                                                 ['B']   typeform
# 1652                                             ['Male']   typeform
# 3132    ['Yes - Marketing (this could include social m...   typeform
# 3328    ['Yes - Science (for use in our algorithm so w...   typeform
# 4446    ['My cat does not have any white on their feet...   typeform
# ...                                                   ...        ...
# 645670                                  ['None of these']   basepaws
# 651550                                  ['None of these']   basepaws
# 657430                                               ['']   basepaws
# 663297                                        ['Neither']   basepaws
# 667031                                  ['None of These']   basepaws
#
#                                                    text_y  \
# 171     Does your cat have a little "junk in the trunk...
# 1652                         Is your cat a king or queen?
# 3132    Do you give Basepaws permission to use your ca...
# 3328    Do you give Basepaws permission to use your ca...
# 4446    Does you cat have white legs, feet or paws? If...
# ...                                                   ...
# 645670  Does your cat suffer from issues that fall und...
# 651550  Which, if any, of the following signs of poten...
# 657430  Which, if any, of the following preventative d...
# 663297  Does your cat bring you gifts and carry toys/o...
# 667031  Has your cat ever been diagnosed by a veterina...
#
#                                                   answers
# 171                                  ['A', 'B', 'C', 'D']
# 1652                                   ['Female', 'Male']
# 3132    ['Yes - Marketing (this could include social m...
# 3328    ['Yes - Marketing (this could include social m...
# 4446    ['My cat does not have any white on their feet...
# ...                                                   ...
# 645670  ['Periodontal disease', 'Gingivitis', 'Periodo...
# 651550  ['Broken or discolored teeth', 'Bad breath', '...
# 657430  ['Drinking Water Additive', 'Oral Rinse', 'Den...
# 663297  ['Gifting behavior', 'Mothering behavior', 'Ne...
# 667031  ['Gingivitis', 'Periodontal disease', 'Tooth R...
#
# [172 rows x 7 columns]
